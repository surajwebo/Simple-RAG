# %% [markdown]
# <a href="https://colab.research.google.com/github/surajwebo/Simple-RAG/blob/main/Simple_RAG.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install sentence-transformers

# %%
pip install scikit-learn

# %%
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity

# 1. Create model
model = SentenceTransformer(
    'all-MiniLM-L6-v2'
)


# 2. Create knowledge base
docs = [
    'Python is a Programming Language',
    'Machine Learning uses algorithms',
    'Data Science analyzes data'
]
doc_embeddings = model.encode(docs)


# 3. User Query
query = [
    input('Ask your query - ')
]
query_embedding = model.encode(query)


# 4. Find most relevant doc
similarities = cosine_similarity(
    query_embedding,
    doc_embeddings
)

best_match = docs[similarities.argmax()]
print(best_match)
